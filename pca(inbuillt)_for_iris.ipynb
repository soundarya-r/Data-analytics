# %% [markdown]
# <a href="https://colab.research.google.com/github/soundarya-r/Data-analytics/blob/master/pca(inbuillt)_for_iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

from sklearn import datasets
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from numpy import linalg as la

# %%
iris = datasets.load_iris()

X = iris.data
y = iris.target
target_names = iris.target_names

# %%
plt.figure()
colors = ['red', 'blue', 'green']
lw = 2

for color, i, target_name in zip(colors, [0, 1, 2], target_names):
    plt.scatter(X[y == i, 0], X[y == i, 1], color=color, alpha=.5, lw=lw,
                label=target_name)
plt.legend(loc='best', shadow=False, scatterpoints=1)
plt.title('IRIS dataset')
# Out:
# Text(0.5, 1.0, 'IRIS dataset')

# %%
pca = PCA(n_components=2)
X_r = pca.fit(X).transform(X)

# %%
plt.figure()
colors = ['red', 'green', 'yellow']
lw = 2

for color, i, target_name in zip(colors, [0, 1, 2], target_names):
    plt.scatter(X_r[y == i, 0], X_r[y == i, 1], color=color, alpha=.8, lw=lw,
                label=target_name)
plt.legend(loc='best', shadow=False, scatterpoints=1)
plt.title('PCA ')
# Out:
# Text(0.5, 1.0, 'PCA ')

# %%
X_rev = pca.inverse_transform(X_r)
X_rev2 = X_r.dot(pca.components_) + pca.mean_

# %%
loss = ((X - X_rev2) ** 2).mean()
loss
# Out:
# 0.02534107393239825
